# %%
import pandas as pd
import numpy as np

# %%
res = pd.read_csv('', delim_whitespace=True, header = None)

# %%
df = pd.DataFrame()
for i in range(6):
    df = pd.concat([df, res.iloc[0+(i*50):(i+1)*50].reset_index()], axis = 1, ignore_index= True)

# %%
df.columns[[0,1,4,5,8,9,12,13,16,17,20,21]]
# Out:
# Int64Index([0, 1, 4, 5, 8, 9, 12, 13, 16, 17, 20, 21], dtype='int64')

# %%
df.drop(df.columns[[0,1,4,5,8,9,12,13,16,17,20,21]], axis = 1, inplace = True)

# %%
df = df.applymap(lambda x: x.lstrip('train-error:'))

# %%
df = df.applymap(lambda x: x.lstrip('val-error:'))

# %%
for i,j in enumerate(range(2,23,4)):
    df.rename(columns={j: 'train_error'+'_'+str(i)}, inplace = True)
for i,j in enumerate(range(3,24,4)):
    df.rename(columns={j: 'eval_error'+'_'+str(i)}, inplace = True)

# %%
#reorder columns of results
df = pd.read_pickle('')
cols = df.columns.tolist()
cols = cols[0::2] + cols[1::2]
df = df[cols]
df['mean'] = df.iloc[:,-6:].astype(np.float).mean(axis = 1)

# %%
df.to_pickle('')

# %%
pd.concat([df.iloc[:,-7:], df1.iloc[:,-7:]], axis = 1)[25:45]
# Out:
#    eval_error_0 eval_error_1 eval_error_2 eval_error_3 eval_error_4  \
# 25     0.135678     0.141424     0.140761     0.144119     0.146875
# 26     0.135653     0.141055     0.140779     0.144033     0.146421
# 27     0.135836     0.141397     0.140869     0.144215     0.146340
# 28     0.135704     0.141566     0.141044     0.144040     0.146146
# 29     0.135455     0.141847     0.140704     0.143473     0.146246
# 30     0.135330     0.141344     0.140557     0.143694     0.146603
# 31     0.135534     0.141377     0.140331     0.143341     0.146473
# 32     0.135638     0.141341     0.140201     0.143357     0.145906
# 33     0.135047     0.141630     0.140423     0.143189     0.146132
# 34     0.135216     0.141612     0.140372     0.143233     0.146158
# 35     0.135800     0.141035     0.140025     0.143470     0.146716
# 36     0.135644     0.141257     0.140052     0.143401     0.146278
# 37     0.135532     0.141115     0.139884     0.143291     0.146204
# 38     0.135857     0.141290     0.140015     0.143705     0.146132
# 39     0.135695     0.141349     0.140118     0.143694     0.145793
# 40     0.135738     0.141531     0.140125     0.143792     0.145691
# 41     0.136190     0.141221     0.140076     0.143552     0.146067
# 42     0.136141     0.141069     0.140356     0.143807     0.146151
